# %% [markdown]
# <a href="https://colab.research.google.com/github/binarymath/Improving_in_python/blob/main/TrabalhandoComImagem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Pillow

# %%
from PIL import Image

# %%
image = Image.open("cachorro.jpg")

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x960>
